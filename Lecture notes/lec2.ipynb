# %% [markdown]
# # Sta130 lecture 2 Notes

# %% [markdown]
# ##### Take up from last time
# We did not do logical conditionals for the purpose of logical selection

# %%
import pandas as pd
url = "https://raw.githubusercontent.com/KeithGalli/pandas/master/pokemon_data.csv"
# fail https://github.com/KeithGalli/pandas/blob/master/pokemon_data.csv
pokeaman = pd.read_csv(url)
pokeaman
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %% [markdown]
# ### Sort values!
# What is the most powerful pokemon? (by attack)
# Initially sorted by ascending

# %%
pokeaman.sort_values('Attack', ascending=False)
# Out:
#        #                     Name   Type 1    Type 2   HP  Attack  Defense  \
# 163  150      MewtwoMega Mewtwo X  Psychic  Fighting  106     190      100
# 232  214  HeracrossMega Heracross      Bug  Fighting   80     185      115
# 424  383    GroudonPrimal Groudon   Ground      Fire  100     180      160
# 426  384    RayquazaMega Rayquaza   Dragon    Flying  105     180      100
# 429  386       DeoxysAttack Forme  Psychic       NaN   50     180       20
# ..   ...                      ...      ...       ...  ...     ...      ...
# 139  129                 Magikarp    Water       NaN   20      10       55
# 261  242                  Blissey   Normal       NaN  255      10       10
# 230  213                  Shuckle      Bug      Rock   20      10      230
# 121  113                  Chansey   Normal       NaN  250       5        5
# 488  440                  Happiny   Normal       NaN  100       5        5
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %% [markdown]
# Look at the legendary column, what if we want to subset to only include pokemon who are legendary

# %%
pokeaman[pokeaman['Legendary']]
# Out:
#        #                 Name    Type 1    Type 2   HP  Attack  Defense  \
# 156  144             Articuno       Ice    Flying   90      85      100
# 157  145               Zapdos  Electric    Flying   90      90       85
# 158  146              Moltres      Fire    Flying   90     100       90
# 162  150               Mewtwo   Psychic       NaN  106     110       90
# 163  150  MewtwoMega Mewtwo X   Psychic  Fighting  106     190      100
# ..   ...                  ...       ...       ...  ...     ...      ...
# 795  719              Diancie      Rock     Fairy   50     100      150
# 796  719  DiancieMega Diancie      Rock     Fairy   50     160      110
# 797  720  HoopaHoopa Confined   Psychic     Ghost   80     110       60
# 798  720   HoopaHoopa Unbound   Psychic      Dark   80     160       60
# 799  721            Volcanion      Fire     Water   80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
# creates a dataframe with true false values!
# pokeaman['Type 2'] == "Ghost"
pokeaman[pokeaman['Type 2'] == "Ghost"]
# Out:
#        #                   Name    Type 1 Type 2   HP  Attack  Defense  \
# 316  292               Shedinja       Bug  Ghost    1      90       45
# 326  302                Sableye      Dark  Ghost   50      75       75
# 327  302    SableyeMega Sableye      Dark  Ghost   50      85      125
# 530  478               Froslass       Ice  Ghost   70      80       70
# 531  479                  Rotom  Electric  Ghost   50      50       77
# 653  592               Frillish     Water  Ghost   55      40       50
# 654  593              Jellicent     Water  Ghost  100      60       70
# 683  622                 Golett    Ground  Ghost   59      74       50
# 684  623                 Golurk    Ground  Ghost   89     124       80
# 748  679                Honedge     Steel  Ghost   45      80      100
# 749  680               Doublade     Steel  Ghost   59     110      150
# 750  681   AegislashBlade Forme     Steel  Ghost   60     150       50
# ...

# %%
# Composite logical conditional
pokeaman[(pokeaman['Type 1']=="Ghost") & (pokeaman['Type 2']=="Ghost")]
# Out:
# Empty DataFrame
# Columns: [#, Name, Type 1, Type 2, HP, Attack, Defense, Sp. Atk, Sp. Def, Speed, Generation, Legendary]
# Index: []

# %%
# The other one (or)
pokeaman[(pokeaman['Type 1']=="Ghost") | (pokeaman['Type 2']=="Ghost")]
# Out:
#        #                   Name    Type 1  Type 2   HP  Attack  Defense  \
# 99    92                 Gastly     Ghost  Poison   30      35       30
# 100   93                Haunter     Ghost  Poison   45      50       45
# 101   94                 Gengar     Ghost  Poison   60      65       60
# 102   94      GengarMega Gengar     Ghost  Poison   60      65       80
# 215  200             Misdreavus     Ghost     NaN   60      60       60
# 316  292               Shedinja       Bug   Ghost    1      90       45
# 326  302                Sableye      Dark   Ghost   50      75       75
# 327  302    SableyeMega Sableye      Dark   Ghost   50      85      125
# 385  353                Shuppet     Ghost     NaN   44      75       35
# 386  354                Banette     Ghost     NaN   64     115       65
# 387  354    BanetteMega Banette     Ghost     NaN   64     165       75
# 388  355                Duskull     Ghost     NaN   20      40       90
# ...

# %%
# How to get the pokeman with the lowest attack and highest defence
pokeaman[(pokeaman['Attack'] < 50) & (pokeaman['Defense'] > 70)]
# Out:
#        #                Name   Type 1   Type 2   HP  Attack  Defense  Sp. Atk  \
# 103   95                Onix     Rock   Ground   35      45      160       30
# 110  102           Exeggcute    Grass  Psychic   60      40       80       60
# 149  138             Omanyte     Rock    Water   35      40      100       90
# 190  176             Togetic    Fairy   Flying   55      40       85       80
# 230  213             Shuckle      Bug     Rock   20      10      230       10
# 314  290             Nincada      Bug   Ground   31      45       90       30
# 323  299            Nosepass     Rock      NaN   30      45      135       45
# 377  345              Lileep     Rock    Grass   66      41       77       61
# 388  355             Duskull    Ghost      NaN   20      40       90       30
# 455  410            Shieldon     Rock    Steel   30      42      118       42
# 484  436             Bronzor    Steel  Psychic   57      24       86       24
# ...

# %% [markdown]
# #### Difference between indexing
# iloc[rows_slice, cols_slice] -> gives square of data within slice
# loc[rows_slice, col_names] -> gives rows slice and indexes of cols (loc slice is inclusive??)

# %%
pokeaman.iloc[0:10, 0:3]
# Out:
#    #                       Name Type 1
# 0  1                  Bulbasaur  Grass
# 1  2                    Ivysaur  Grass
# 2  3                   Venusaur  Grass
# 3  3      VenusaurMega Venusaur  Grass
# 4  4                 Charmander   Fire
# 5  5                 Charmeleon   Fire
# 6  6                  Charizard   Fire
# 7  6  CharizardMega Charizard X   Fire
# 8  6  CharizardMega Charizard Y   Fire
# 9  7                   Squirtle  Water

# %%
pokeaman.loc[0:10, ['Name', 'Attack', 'Defense']]
# Out:
#                          Name  Attack  Defense
# 0                   Bulbasaur      49       49
# 1                     Ivysaur      62       63
# 2                    Venusaur      82       83
# 3       VenusaurMega Venusaur     100      123
# 4                  Charmander      52       43
# 5                  Charmeleon      64       58
# 6                   Charizard      84       78
# 7   CharizardMega Charizard X     130      111
# 8   CharizardMega Charizard Y     104       78
# 9                    Squirtle      48       65
# 10                  Wartortle      63       80

# %%
# Can do like this instead
pokeaman[0:10][['Attack', 'Defense', 'Name']]
# Out:
#    Attack  Defense                       Name
# 0      49       49                  Bulbasaur
# 1      62       63                    Ivysaur
# 2      82       83                   Venusaur
# 3     100      123      VenusaurMega Venusaur
# 4      52       43                 Charmander
# 5      64       58                 Charmeleon
# 6      84       78                  Charizard
# 7     130      111  CharizardMega Charizard X
# 8     104       78  CharizardMega Charizard Y
# 9      48       65                   Squirtle

# %% [markdown]
# ### Probability
# $Pr(A) \text{ or } Pr(X = x)$
# Capital X is the idea
# Lowercase x is the actual value
#
# ##### Conditional Probability
# $\huge Pr(A | B) \small \text{ or } Pr(Y = y | X = x)$
# Probability of A given B
# Probability its going to rain GIVEN that it is January
#
# A chatbot is a conditional probability model, looks at the posible choices and picks one based on the probability of using it.
#
# ##### Example using markov chains
# Probability of the current word given the previous word!
# Markov: $Pr(W_{i + 1} = w_{i + 1} | W_{i} = w_{i})$
# Bigram: $Pr(W_{i + 2} = w_{i + 1} | W_{i + 1} = w_{i + 1}, W_{i} = w_{i})$
# Trigram: $Pr(W_{i + 3} = w_{i + 3} | W_{i + 2} = w_{i + 2}, W_{i + 1} = w_{i + 1}, W_{i} = w_{i})$
# Context: $Pr(W_{i + 3} = w_{i + 3} | W_{i + 1} = w_{i + 1}, W_{i} = w_{i}, C = c)$
#
# ### Statistical indepedence
# Two events A and B are independent if:
# # $Pr(A) = Pr(A | B)$
# If a chatBot was independent, they would output garbage (random)

# %% [markdown]
# ### Multinomial Distribution
# Given a certain number of things that have a chance of being selected, pick the next things based on the chances of each items
#
# Example:
# Picking bags of chips from the store, instead of picking 1 back, pick some number of chips
# Jalapeno cheddar chips is favorite?

# %%
import numpy as np
from scipy import stats # Science modules for python
# P is the chance of each thing you can get
# Model is not correct since it will use statistical independece
# Events are not independant -> picking is not random
# If doritoes are already picked, then pick second bag for variety
stats.multinomial(n=2, p=[0.9, 0.05, 0.05]).rvs(size=1)
# Out:
# array([[2, 0, 0]])

# %% [markdown]
# Why did you say chatbot is multinomial but is not independant?
#
# Probabilities of multinomial change depending on the context!
# It is not constantly drawing from the same multinomial.
#
# `np.random.choice(options, size=draws, repalce=True, p=None)` is a multinomial distribution.  Take a look at wiki-textbook for more information

# %% [markdown]
# ##### Using a seed
# `np.random.seed(initialization)`

# %% [markdown]
# # Summary
# ##### Accessing Items using logical boolean conditionals
# `iloc[row_slice, col_slice]`
# `loc[row_slice, col_names]`
# `df[row_slice][col_names]`
#
# ##### Probabilities
# $Pr(A)$ denotes the probability of an event A occuring
# $Pr(A | B)$ denotes the probability of an event A occuring given that B also occured
#
# ##### Multinomial Distribution
# Selecting the chance of many events occuring given a list of probaibilties for each event.

# %% [markdown]
# # Easter Egg
# A blue flag beach is water that has been tested
# Lake O is blue flag -> maybe go swim in it
#
# Do you know how to do composite (multi-part) boolean selection using logical conditionals (with &, |, and ~) to select data? Can you use tuple, list, and dict object types appropriately? How about using a for loop based on a list or not based on a list using range(n) correctly with 0-based indexing?
#
# Do you know what scipy.stats.multinomial and np.random.choice have in common (and what they don't), and what independence and conditional probability might (or might not) have to do with them?

# %%
import pandas as pd
url = "https://raw.githubusercontent.com/rfordatascience/tidytuesday/master/data/2020/2020-08-11/avatar.csv"
avatar = pd.read_csv(url) #avatar.isnull().sum() #avatar[avatar.isnull().sum(axis=1)>0]
# every row is a sequence of events that occur in avatar
avatar
# Out:
#           id   book  book_num                             chapter  \
# 0          1  Water         1              The Boy in the Iceberg
# 1          2  Water         1              The Boy in the Iceberg
# 2          3  Water         1              The Boy in the Iceberg
# 3          4  Water         1              The Boy in the Iceberg
# 4          5  Water         1              The Boy in the Iceberg
# ...      ...    ...       ...                                 ...
# 13380  13381   Fire         3  Sozin's Comet, Part 4: Avatar Aang
# 13381  13382   Fire         3  Sozin's Comet, Part 4: Avatar Aang
# 13382  13383   Fire         3  Sozin's Comet, Part 4: Avatar Aang
# 13383  13384   Fire         3  Sozin's Comet, Part 4: Avatar Aang
# 13384  13385   Fire         3  Sozin's Comet, Part 4: Avatar Aang
#
#        chapter_num          character  \
# 0                1             Katara
# 1                1  Scene Description
# 2                1              Sokka
# ...

# %%
# regex and string manipulation is NOT TESTED
print((avatar['character'].str.upper() + ": " + avatar['full_text'] + "\n\n").values[:4].sum())
# Out:
# KATARA: Water. Earth. Fire. Air. My grandmother used to tell me stories about the old days: a time of peace when the Avatar kept balance between the Water Tribes, Earth Kingdom, Fire Nation and Air Nomads. But that all changed when the Fire Nation attacked. Only the Avatar mastered all four elements; only he could stop the ruthless firebenders. But when the world needed him most, he vanished. A hundred years have passed, and the Fire Nation is nearing victory in the war. Two years ago, my father and the men of my tribe journeyed to the Earth Kingdom to help fight against the Fire Nation, leaving me and my brother to look after our tribe. Some people believe that the Avatar was never reborn into the Air Nomads and that the cycle is broken, but I haven't lost hope. I still believe that, somehow, the Avatar will return to save the world.
#
# ...

# %% [markdown]
# ##### You can grab columns as if they were attributes
# `avatar.character == avatar['character']`

# %%
avatar.character.value_counts() # Count num times each character speaks
# Out:
# character
# Scene Description    3393
# Aang                 1796
# Sokka                1639
# Katara               1437
# Zuko                  776
#                      ...
# The Hippo               1
# Audience                1
# Young Mai               1
# Old woman               1
# Katara and Sokka        1
# Name: count, Length: 374, dtype: int64

# %%
avatar.chapter.value_counts() # How long each chapter is (number of character dialogue)
# Out:
# chapter
# The Fortuneteller                          331
# The Warriors of Kyoshi                     304
# City of Walls and Secrets                  293
# Jet                                        290
# The Desert                                 286
#                                           ...
# The Siege of the North, Part 2             161
# Sozin's Comet, Part 3: Into the Inferno    151
# The Blue Spirit                            144
# Appa's Lost Days                           106
# Sozin's Comet, Part 4: Avatar Aang          91
# Name: count, Length: 61, dtype: int64

# %%
avatar.groupby("chapter")[['imdb_rating', 'chapter_num', 'book', 'director']].describe(include='all')
# Out:
#                                           imdb_rating                       \
#                                                 count unique top freq mean
# chapter
# Appa's Lost Days                                106.0    NaN NaN  NaN  8.8
# Avatar Day                                      247.0    NaN NaN  NaN  7.5
# Bato of the Water Tribe                         267.0    NaN NaN  NaN  7.9
# Bitter Work                                     177.0    NaN NaN  NaN  8.6
# City of Walls and Secrets                       293.0    NaN NaN  NaN  8.7
# ...                                               ...    ...  ..  ...  ...
# The Waterbending Scroll                         223.0    NaN NaN  NaN  8.0
# The Western Air Temple                          195.0    NaN NaN  NaN  8.9
# Winter Solstice, Part 1: The Spirit World       181.0    NaN NaN  NaN  8.2
# Winter Solstice, Part 2: Avatar Roku            221.0    NaN NaN  NaN  8.9
# ...

# %%
# The entire script of avatar
words = ("\n"+avatar.character.str.upper().str.replace(' ','.')+": "+avatar.full_text+" ").sum().split(' ')
print(*words)
# Out:
# KATARA: Water. Earth. Fire. Air. My grandmother used to tell me stories about the old days: a time of peace when the Avatar kept balance between the Water Tribes, Earth Kingdom, Fire Nation and Air Nomads. But that all changed when the Fire Nation attacked. Only the Avatar mastered all four elements; only he could stop the ruthless firebenders. But when the world needed him most, he vanished. A hundred years have passed, and the Fire Nation is nearing victory in the war. Two years ago, my father and the men of my tribe journeyed to the Earth Kingdom to help fight against the Fire Nation, leaving me and my brother to look after our tribe. Some people believe that the Avatar was never reborn into the Air Nomads and that the cycle is broken, but I haven't lost hope. I still believe that, somehow, the Avatar will return to save the world.
# ...

# %%
# from collections import defaultdict
word_used = dict() # defaultdict(int)
next_word = dict() # defaultdict(lambda: defaultdict(int))
for i,word in enumerate(words[:-1]):
    
    if word in word_used:
        word_used[word] += 1
    else: 
        word_used[word] = 1
        next_word[word] = {}
        
    if words[i+1] in next_word[word]:
        next_word[word][words[i+1]] += 1 
    else:

        next_word[word][words[i+1]] = 1

# %%
next_word
# Out:
# {'\nKATARA:': {'Water.': 2,
#   '[Happily': 1,
#   '[Struggling': 2,
#   '[Exclaims': 1,
#   '[Cut': 13,
#   'Watch': 1,
#   '[A': 3,
#   '[Indignantly.]': 1,
#   'You': 34,
#   'Ever': 1,
#   '[Close-up': 8,
#   'No': 8,
#   '[Astonished.]': 1,
#   "He's": 5,
#   '[Waves': 2,
#   'What?': 7,
#   '[Curiously.]': 4,
#   '[Awkwardly.]': 2,
#   '[Pushes': 1,
#   '[Gasps': 1,
#   "We'd": 2,
#   '[While': 2,
#   '[Uncomfortably.]': 1,
#   'Hey.': 2,
#   'I': 76,
#   'Okay.': 2,
#   'Aang?': 4,
#   'Aang,': 39,
#   '[Gesturing.]': 1,
#   '[Offering': 1,
#   '[Nervously.]': 5,
#   '[Excitedly.]': 11,
#   'But': 18,
#   '[Runs': 1,
#   '[Amused.]': 3,
#   '[Sadly.]': 4,
#   'Maybe,': 1,
#   '[Unsure.]': 2,
#   '[Mockingly': 2,
#   '[Happily.]': 2,
#   '[On': 1,
#   '[Her': 1,
#   'Think': 2,
#   '[Squats': 1,
#   '[Smiling': 3,
#   'Aaah!': 1,
#   '[Protesting.]': 1,
#   '[Irritably,': 1,
#   '[Angrily.]': 17,
#   '[Pleading.]': 3,
#   '[Outraged.]': 1,
#   '[Upset.]': 2,
#   '[Still': 4,
# ...

# %%
import numpy as np
from scipy import stats
current_word = "\nKatara:".upper()
print(current_word, end=" ")
for i in range(100):
    # Takes the count of each next possible word, divides by total sum of all values (word_used) for multinomial distribution
    probability_of_next_wrord = np.array(list(next_word[current_word].values()))/word_used[current_word]
    # Chose a random word from the multinomial distribution returns an array of {0, 1} values (1 means word was selected)
    randomly_chosen_next_word = stats.multinomial(p=probability_of_next_wrord, n=1).rvs(size=1)[0,:]
    # print(f"{randomly_chosen_next_word = }")
    # Return the word marked with 1
    current_word = np.array(list(next_word[current_word].keys()))[1==randomly_chosen_next_word][0]
    print(current_word, end=' ')

"""
KATARA: [Reads through, becomes annoyed. The camera focuses on the king on the air.] Aha! I think you were taken. I forget it. As Zuko into position before charging at Toph, ready a loud cling; he does this guy? [Turns around, stressed. I'm powerless. 
KATARA: Aang, who pass through. 
BATO: Any day in on board a goat gorilla. 
AANG: So Chit Sang notices a large door together, looking at the right.
Cut to a while. [Walks over her mood.] I'm not appear.] What? [Turns angrily, but frankly, your arm. 
LEE: Hey! Over there! 
SCENE.DESCRIPTION: A podium-like devise suddenly falls back into a 
"""
# Out:
# KATARA: [Angrily.] Rotten eggs! Then, just so sorry, but once called fire between two women in there‌?
# SCENE.DESCRIPTION: Sokka, who takes a muscly version of Chin says this. The camera switches view of Aang can make sure you'll be a profile of the Zhang camp.
# KATARA: [Crosses arms crossed.
# SOKKA: He smiles and Sokka. I call the tunnel, freeing Ozai sits next to discover you're going to lose my dad's an excuse.] Aha! [Showing the camera pans above him.] Where are standing in the cell.] Hey! It's a monk, while the environment to the incline leading the North Pole seas. Sokka
# ...

# %%
import re
from collections import defaultdict
avatar.full_text = avatar.full_text.apply(lambda string: re.sub(r'\[.*?\]', lambda match: match.group(0).replace(' ', '_ '), string))
avatar.loc[avatar.character=='Scene Description','full_text'] = avatar.full_text[avatar.character=='Scene Description'].str.replace(' ', '- ')
words = ("\n"+avatar.character.str.upper().str.replace(' ','.')+": "+avatar.full_text+" ").sum().split(' ')

# %%
word_used2 = defaultdict(int)
next_word2 = defaultdict(lambda: defaultdict(int))
for i,word in enumerate(words[:-2]):
    word_used2[word+' '+words[i+1]] += 1
    next_word2[word+' '+words[i+1]][words[i+2]] += 1

# %%
current_word_1 = "\nKatara:".upper()
current_word_2 = "The"
print(current_word_1, end=' ')
print(current_word_2, end=' ')
for i in range(200):
    probability_of_next_word = np.array(list(next_word2[current_word_1+' '+current_word_2].values()))/word_used2[current_word_1+' '+current_word_2]
    randomly_chosen_next_word = stats.multinomial(p=probability_of_next_word, n=1).rvs(size=1)[0,:]
    current_word_1,current_word_2 = current_word_2,np.array(list(next_word2[current_word_1+' '+current_word_2].keys()))[1==randomly_chosen_next_word][0]
    print(current_word_2.replace('_', '').replace('-', ''), end=' ')

"""
KATARA: The thing is, Aang can talk to you. [Bows to her.] Something that's coming for you, Dad. 
TYRO: If we can close our eyes just for a free fish and I go there on the sheet of paper, but I can't! The invasion's tomorrow! 
KATARA: [Concerned.] Aang, what are we going to give girls space when they do that? 
CANYON.GUIDE: These people should be ashamed of yourself that you had no choice. Please, we're just simple refugees. 
PAO: [Pointing to his sister with a grin.] dethrone him! 
VILLAGER: That's him over and I know what it's supposed to be handsome? [Clasps her hands together and uses his airbending as Katara hits him in the box.] I am keeping her at a most reasonable price, free. [Rolls the scroll to find it.] Where? Where? 
SCENE.DESCRIPTION: A platypus bear attempts to land softly and gets thrown away from the table for new pastries to snatch. 
AANG: [Lowers his arm over Aang's shoulder and over his heart; begins to leave.] 
ZUKO: You'll have to trust his instincts. 
KATARA: [Sarcastically.] Okay, we'll try it your home. 
SCENE.DESCRIPTION: Cut to the outside of the cliff path. They are imprisoned in metal cages.
"""
# Out:
# KATARA: The Dai Li are the Avatar!
# SCENE.DESCRIPTION: Sokka startles at the scroll. Zuko gasps and runs away.
# AANG: [To Appa.] Shhh.
# SCENE.DESCRIPTION: Appa flies through to the ground behind her. She fires a blast of air that blows them out of the lips, which smile. Cut to a shot of the cave, where Aang dances playfully, suspended in the middle with a smile gracing his lips upon realizing he will be spared. Without saying another word, Katara turns around, the colored scents of humans are shown. Nyla soon finds himself alone in the apartment across theirs.
# IROH: Would you like your legendary failure at Ba Sing Se can hide no longer!
# SCENE.DESCRIPTION: Actress Azula jumps over another dune.
# KATARA: What should we do?
# TOPH: [Pops out of the model ship.] Well, while you wait!
# SCENE.DESCRIPTION: Pao pours some tea and bows slightly toward Azula.
# MAI: Please tell me ... hopeful again.
# ...

# %%
import pandas as pd
import numpy as np
from scipy import stats
import re
from collections import defaultdict

url = "https://raw.githubusercontent.com/rfordatascience/tidytuesday/master/data/2020/2020-08-11/avatar.csv"
avatar = pd.read_csv(url) #avatar.isnull().sum() #avatar[avatar.isnull().sum(axis=1)>0]
words = ("\n"+avatar.character.str.upper().str.replace(' ','.')+": "+avatar.full_text+" ").sum().split(' ')

# Change words based on whether or not in a description
# replace all descriptions to have dashes in between
# All action blocks now have underscore in between words
avatar.full_text = avatar.full_text.apply(lambda string: re.sub(r'\[.*?\]', lambda match: match.group(0).replace(' ', '_ '), string))
avatar.loc[avatar.character=='Scene Description','full_text'] = avatar.full_text[avatar.character=='Scene Description'].str.replace(' ', '- ')
words = ("\n"+avatar.character.str.upper().str.replace(' ','.')+": "+avatar.full_text+" ").sum().split(' ')

# Markovian chatbot that uses a concatenation of two previous words
word_used2 = defaultdict(int)
next_word2 = defaultdict(lambda: defaultdict(int))
for i,word in enumerate(words[:-2]):
    word_used2[word+' '+words[i+1]] += 1
    next_word2[word+' '+words[i+1]][words[i+2]] += 1 

current_word_1 = "\nKatara:".upper()
current_word_2 = "Water."
print(current_word_1, end=' ')
print(current_word_2, end=' ')
for i in range(200):
    probability_of_next_word = np.array(list(next_word2[current_word_1+' '+current_word_2].values()))/word_used2[current_word_1+' '+current_word_2]
    randomly_chosen_next_word = stats.multinomial(p=probability_of_next_word, n=1).rvs(size=1)[0,:]
    current_word_1,current_word_2 = current_word_2,np.array(list(next_word2[current_word_1+' '+current_word_2].keys()))[1==randomly_chosen_next_word][0]
    print(current_word_2.replace('_', '').replace('-', ''), end=' ')
# Out:
# KATARA: Water. Earth. Fire. Air. My grandmother used to escape. [Scene fades to an overhead shot of the Eternal Flame. Aang, Zuko, and Azula. To Zuko, Mai, and Azula.] This much negative energy is the worst part of the Fire Nation, just like me too much.
# SCENE.DESCRIPTION: Scene changes to Toph to move up and starts to stuff his face. Cut to an image of Yue. Sideview of Sokka who are working to bring up a gentle poke to get away, Katara violently pushes the corporal's hand to block the entranceway. He proceeds by earthbending a rock angel. After she is practicing waterbending before switching to an aerial shot of Aang as the camera pans to the dock. Cut to Ghashiun and a ladle, climbing on top of them.
# LONG.FENG: Don't worry, you'll all need me more about fire than we'd hoped. [Aang shows up.] Aang!
# ...

# %%
word_used3 = defaultdict(int)
next_word3 = defaultdict(lambda: defaultdict(int))
for i,word in enumerate(words[:-3]):
    word_used3[word+' '+words[i+1]+' '+words[i+2]] += 1
    next_word3[word+' '+words[i+1]+' '+words[i+2]][words[i+3]] += 1

# %%
current_word_1 = "\nKatara:".upper()
current_word_2 = "Water."
current_word_3 = "Earth."
print(current_word_1, end=' ')
print(current_word_2, end=' ')
print(current_word_3, end=' ')
for i in range(200):
    probability_of_next_word = np.array(list(next_word3[current_word_1+' '+current_word_2+' '+current_word_3].values()))/word_used3[current_word_1+' '+current_word_2+' '+current_word_3]
    randomly_chosen_next_word = stats.multinomial(p=probability_of_next_word, n=1).rvs(size=1)[0,:]
    current_word_1,current_word_2,current_word_3 = current_word_2,current_word_3,np.array(list(next_word3[current_word_1+' '+current_word_2+' '+current_word_3].keys()))[1==randomly_chosen_next_word][0]
    print(current_word_3.replace('_', '').replace('-', ''), end=' ')
# Out:
# KATARA: Water. Earth. Fire. Air. Long ago, the four nations lived together in harmony. Then, everything changed when the Fire Nation should be right up here.
# AANG: [Looking at a meat display.] Oh, we're going to save our lives now? We'll never make it onto the gondola. There's too many of them!
# AANG: Let's join the others! [Dodges another fireball.]
# SCENE.DESCRIPTION: Cuts to shot of Aang, who is nervously shaking. She walks over to his right, sending him into the saddle. Momo leaps up and down. This is followed by shaking and the ground starts shaking. Cut to inside the prison as the struggle continues.
# FEMALE.GUARD: Get him off me and arrest him!
# SOKKA: [Grabs Zuko and throws him down on the bench without a care.] Like we'll ever run into Jeong Jeong again.
# TOPH: [Curiously.] Who's ... oh, [She folds her arms irritably.] never mind. If it's important I'll find out.
# AANG: Oh well, guess we can't come up with something after a short nap. [Smiles.]
# ...

# %%
word_used4 = defaultdict(int)
next_word4 = defaultdict(lambda: defaultdict(int))
for i,word in enumerate(words[:-4]):
    word_used4[word+' '+words[i+1]+' '+words[i+2]+' '+words[i+3]] += 1
    next_word4[word+' '+words[i+1]+' '+words[i+2]+' '+words[i+3]][words[i+4]] += 1

# %%
current_word_1 = "\nKatara:".upper()
current_word_2 = "Water."
current_word_3 = "Earth."
current_word_4 = "Fire."
print(current_word_1, end=' ')
print(current_word_2, end=' ')
print(current_word_3, end=' ')
print(current_word_4, end=' ')
for i in range(200):
    probability_of_next_word = np.array(list(next_word4[current_word_1+' '+current_word_2+' '+current_word_3+' '+current_word_4].values()))/word_used4[current_word_1+' '+current_word_2+' '+current_word_3+' '+current_word_4]
    randomly_chosen_next_word = stats.multinomial(p=probability_of_next_word, n=1).rvs(size=1)[0,:]
    current_word_1,current_word_2,current_word_3,current_word_4 = current_word_2,current_word_3,current_word_4,np.array(list(next_word4[current_word_1+' '+current_word_2+' '+current_word_3+' '+current_word_4].keys()))[1==randomly_chosen_next_word][0]
    print(current_word_4.replace('_', '').replace('-', ''), end=' ')
# Out:
# KATARA: Water. Earth. Fire. Air. My grandmother used to tell me stories about the old days: a time of peace when the Avatar kept balance between the Water Tribes, Earth Kingdom, Fire Nation and Air Nomads. But that all changed when the Fire Nation attacked. Only the Avatar mastered all four elements; only he could stop the ruthless firebenders. But when the world needed him most, he vanished. A hundred years have passed, and the Fire Nation would have to start searching all over again. So I'll keep you alive, but just barely. [Aang takes a deep breath before finally speaking.] You're right. I'm losing my mind. [Desperately.] Please, Uncle, I'm so confused I need your help.
# SCENE.DESCRIPTION: Sokka is shown with a fly buzzing around him. He does not seems scared anymore.
# SOKKA: Please, we're all alone out here.
# ...

# %%
n = 5
word_used_n = defaultdict(int)
next_word_n = defaultdict(lambda: defaultdict(int))
for i,word in enumerate(words[:-n]):
    word_used_n[' '.join(words[i:i+n])] += 1
    next_word_n[' '.join(words[i:i+n])][words[i+n]] += 1

# %%
current_words = ["\nKATARA:"] + "Water. Earth. Fire. Air. Long ago, the four nations lived together in harmony. Then, everything changed when the Fire Nation attacked.".split()
current_words = current_words[:n]
print(*current_words[:n], end=' ')
for i in range(400):
    probability_of_next_word = np.array(list(next_word_n[' '.join(current_words[:n])].values()))/word_used_n[' '.join(current_words[:n])]
    randomly_chosen_next_word = stats.multinomial(p=probability_of_next_word, n=1).rvs(size=1)[0,:]
    current_words = current_words[1:] + [np.array(list(next_word_n[' '.join(current_words[:n])].keys()))[1==randomly_chosen_next_word][0]]
    print(current_words[-1].replace('_', '').replace('-', ''), end=' ')
# Out:
# KATARA: Water. Earth. Fire. Air. Long ago, the four nations lived together in harmony. Then, everything changed when the Fire Nation attacked. Only the Avatar mastered all four elements; only he could stop the ruthless firebenders. But when the world needed him most, he vanished. A hundred years passed, and my brother and I discovered the new Avatar, an airbender named Aang. And although his airbending skills are great, he has a lot to learn before he's ready to save anyone. But I believe Aang can save the world.
# SCENE.DESCRIPTION: The episode opens onto the yellowing sky as the flare Aang accidentally launched in the previous episode soars lazily through the air in the distance. The camera pans downward to the ground where Zuko is seen running toward the building. Inside, he runs down a hallway past a guard, who crouches in fear as he passes. He arrives at the entrance to his uncle's prison cell.
# ...
